# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Load and Inspect the Data

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/creditcard.csv")

df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(df.info())
print("Duplicated:")
print(df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ### Summary
# - We have 284807 rows and 31 collumns (30 float and 1 int64)
# - 30 features are numerical and class is category( 1: Fraud and 0: legit)
# - No missing value
# - Collums name is ambiguous

# %% [markdown]
# ## Understand the Target Variable

# %%
df["Class"].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %% [markdown]
# - Dataset is imbalanced with the propotion of class 0 is much more higher than the class 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Class", data=df)
plt.show()

# %% [markdown]
# ### Summary
# - Dataset is imbalance with 0.00173 data belong to fraud.
# - In Fraud Detection, Recall is better metric because missing fraud cases is costly.

# %% [markdown]
# ## Summary Statistics

# %%
fraud = df[df["Class"] == 1]
normal = df[df["Class"] == 0]

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
normal.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %% [markdown]
# ## Explore Numerical Features Distributions

# %%
print(df["Time"].describe())
sns.histplot(df["Time"], bins=50)
plt.show()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %%
print(df["Amount"].describe())
sns.histplot(df["Amount"], bins=50)
plt.show()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# ## Compare Fraud vs. Non‑Fraud Transactions

# %%
fraud[['Amount','Time']].describe()
# Out:
#             Amount           Time
# count   492.000000     492.000000
# mean    122.211321   80746.806911
# std     256.683288   47835.365138
# min       0.000000     406.000000
# 25%       1.000000   41241.500000
# 50%       9.250000   75568.500000
# 75%     105.890000  128483.000000
# max    2125.870000  170348.000000

# %%
normal[['Amount','Time']].describe()
# Out:
#               Amount           Time
# count  284315.000000  284315.000000
# mean       88.291022   94838.202258
# std       250.105092   47484.015786
# min         0.000000       0.000000
# 25%         5.650000   54230.000000
# 50%        22.000000   84711.000000
# 75%        77.050000  139333.000000
# max     25691.160000  172792.000000

# %%
sns.boxplot(x='Class', y='Amount', data=df)
# Out:
# <Axes: xlabel='Class', ylabel='Amount'>

# %%
corr = df.corr()['Class'].drop('Class')

corr_sorted = corr.abs().sort_values(ascending=False)

print(corr_sorted.head(10))
# Out:
# V17    0.326481
# V14    0.302544
# V12    0.260593
# V10    0.216883
# V16    0.196539
# V3     0.192961
# V7     0.187257
# V11    0.154876
# V4     0.133447
# V18    0.111485
# Name: Class, dtype: float64

# %% [markdown]
# ### Summary
# - Fraudulent transaction on average higher in amount but there are some huge transaction in normal transaction.
# - Based on the absolute correlations, top PCA component impact the "Class" collums

# %% [markdown]
# ## Transaction Amount Patterns

# %%
df['Hour'] = (df['Time'] // 3600) % 24
fraud_rate_per_hour = df.groupby('Hour')['Class'].mean()
plt.plot(fraud_rate_per_hour.index, fraud_rate_per_hour.values, marker='o')
plt.xlabel('Hour of Day')
plt.ylabel('Fraud Rate')
plt.title('Fraud Rate by Hour')
plt.show()

# %% [markdown]
# ## Correlation with target

# %%
corr_with_class = df.corr()['Class'].sort_values(ascending=False)
print('Top 10 positive correlations:\n', corr_with_class.head(10))
print('Top 10 negative correlations:\n', corr_with_class.tail(10))
# Out:
# Top 10 positive correlations:
#  Class    1.000000
# V11      0.154876
# V4       0.133447
# V2       0.091289
# V21      0.040413
# V19      0.034783
# V20      0.020090
# V8       0.019875
# V27      0.017580
# V28      0.009536
# Name: Class, dtype: float64
# Top 10 negative correlations:
#  V9    -0.097733
# V1    -0.101347
# V18   -0.111485
# V7    -0.187257
# V3    -0.192961
# V16   -0.196539
# V10   -0.216883
# V12   -0.260593
# V14   -0.302544
# V17   -0.326481
# Name: Class, dtype: float64

# %% [markdown]
# ## Scatter plot of two important features

# %%
sns.scatterplot(x='V11', y='V4', hue='Class', data=df, alpha=0.5)
plt.title('V10 vs V14 colored by Class')
plt.show()
